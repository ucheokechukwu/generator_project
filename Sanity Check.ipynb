# %% [markdown]
# Lessons learnt so far:
#
# * For all-window features: (4,4) conv filters gives a better accuracy.
# * For 1-N-6 window features: A double conv network with 3-dense networks is better
#
# * larger horizons give better performance == greater than 3000. Although there were some outliers at 1200 and 1045.
#
# * KFolding is important.

# %% [markdown]
# **Next Experiments**:
#
# 1. Integration - integrate all the working models so far.
#     * Test Integration to get best convolution (optimum dense outputs from each sub-model)
# 2. New Features
#     * 1. Convolution for predicting N e.g., assuming N==5: N-1-N-2-N-3-N-4-N-6-N, stride 2
#     * 2. Time series for previous N values using Attention?

# %%
import new_model_classes
# Out:
# 2024-03-03 09:28:42.227418: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
